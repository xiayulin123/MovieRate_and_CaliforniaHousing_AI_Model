# %% [markdown]
# # Setting Up the Environment

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Get Data from the dataset

# %%
data = pd.read_csv("Movies_data.csv")

# %%
#check the data
data
# Out:
#        Unnamed: 0      id                        title original_language  \
# 0               0     238                The Godfather                en
# 1               1     278     The Shawshank Redemption                en
# 2               2     240        The Godfather Part II                en
# 3               3   19404  Dilwale Dulhania Le Jayenge                hi
# 4               4     424             Schindler's List                en
# ...           ...     ...                          ...               ...
# 19995       19995  384521      The Cloverfield Paradox                en
# 19996       19996   14361                  Captain Ron                en
# 19997       19997   11637            Are We There Yet?                en
# 19998       19998   10956                     Joe Dirt                en
# 19999       19999   72559        G.I. Joe: Retaliation                en
#
#       release_date  vote_average  popularity  adult
# 0       1972-03-14           8.7     114.574  False
# 1       1994-09-23           8.7      91.998  False
# 2       1974-12-20           8.6      61.490  False
# 3       1995-10-20           8.6      28.989  False
# 4       1993-12-15           8.6      43.764  False
# ...            ...           ...         ...    ...
# 19995   2018-02-04           5.6      17.073  False
# 19996   1992-09-18           5.6      11.060  False
# 19997   2005-01-20           5.6      15.591  False
# 19998   2001-04-10           5.6      15.664  False
# 19999   2013-03-27           5.6      40.449  False
#
# [20000 rows x 8 columns]

# %%
#check data if there is any part missing
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         20000 non-null  int64
#  1   id                 20000 non-null  int64
#  2   title              20000 non-null  object
#  3   original_language  20000 non-null  object
#  4   release_date       20000 non-null  object
#  5   vote_average       20000 non-null  float64
#  6   popularity         20000 non-null  float64
#  7   adult              20000 non-null  bool
# dtypes: bool(1), float64(2), int64(2), object(3)
# memory usage: 1.1+ MB

# %% [markdown]
# # Seperate the Data into X and Y
# ## X = independents Y = dependent

# %%
from sklearn.model_selection import train_test_split

#define what x and y is
X = data.drop(['vote_average'], axis=1) #x is the table without vote_average
Y = data['vote_average'] #y is the table only with vote_average

# %%
X
# Out:
#        Unnamed: 0      id                        title original_language  \
# 0               0     238                The Godfather                en
# 1               1     278     The Shawshank Redemption                en
# 2               2     240        The Godfather Part II                en
# 3               3   19404  Dilwale Dulhania Le Jayenge                hi
# 4               4     424             Schindler's List                en
# ...           ...     ...                          ...               ...
# 19995       19995  384521      The Cloverfield Paradox                en
# 19996       19996   14361                  Captain Ron                en
# 19997       19997   11637            Are We There Yet?                en
# 19998       19998   10956                     Joe Dirt                en
# 19999       19999   72559        G.I. Joe: Retaliation                en
#
#       release_date  popularity  adult
# 0       1972-03-14     114.574  False
# 1       1994-09-23      91.998  False
# 2       1974-12-20      61.490  False
# 3       1995-10-20      28.989  False
# 4       1993-12-15      43.764  False
# ...            ...         ...    ...
# 19995   2018-02-04      17.073  False
# 19996   1992-09-18      11.060  False
# 19997   2005-01-20      15.591  False
# 19998   2001-04-10      15.664  False
# 19999   2013-03-27      40.449  False
#
# [20000 rows x 7 columns]

# %%
Y
# Out:
# 0        8.7
# 1        8.7
# 2        8.6
# 3        8.6
# 4        8.6
#         ...
# 19995    5.6
# 19996    5.6
# 19997    5.6
# 19998    5.6
# 19999    5.6
# Name: vote_average, Length: 20000, dtype: float64

# %% [markdown]
# # Seperate into train dataset and test dataset

# %%
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.2)

# %%
#combine the data to traindata set
train_data = X_train.join(y_train)

# %%
train_data
# Out:
#        Unnamed: 0      id                  title original_language  \
# 17958       17958    9545                 Sniper                en
# 8423         8423  643586     Willy's Wonderland                en
# 13409       13409  639721    The Addams Family 2                en
# 1110         1110   21191             Sin Nombre                es
# 3804         3804   70057                 Dragon                zh
# ...           ...     ...                    ...               ...
# 6293         6293  335051            God Willing                it
# 5565         5565   20024  The End of the Affair                en
# 4959         4959   43645       The Little Devil                it
# 12889       12889   44741              Malicious                it
# 17130       17130   24655                The Car                en
#
#       release_date  popularity  adult  vote_average
# 17958   1993-01-29      22.982  False           6.2
# 8423    2021-02-12      33.034  False           6.1
# 13409   2021-10-01      51.439  False           7.0
# 1110    2009-03-20      25.632  False           7.6
# 3804    2011-07-04       9.092  False           7.0
# ...            ...         ...    ...           ...
# 6293    2015-04-09      11.095  False           6.5
# 5565    1999-12-03      10.988  False           6.6
# 4959    1988-07-01       7.101  False           6.7
# 12889   1973-03-29      35.636  False           7.2
# 17130   1977-05-12      12.892  False           6.3
#
# [16000 rows x 8 columns]

# %%
train_data.original_language.value_counts()
# Out:
# original_language
# en    12133
# fr     1130
# it      684
# ja      520
# es      360
# de      173
# ko      159
# cn      116
# zh      111
# ru       85
# hi       83
# pt       73
# sv       62
# da       56
# no       35
# pl       31
# nl       29
# tr       20
# th       20
# hu       14
# id       13
# fa       11
# fi       10
# cs        6
# te        6
# is        6
# el        6
# uk        5
# ar        5
# sr        4
# xx        4
# ro        4
# bn        3
# eu        3
# et        2
# nb        2
# tn        2
# sh        2
# he        2
# bs        2
# gl        2
# la        2
# ml        1
# mk        1
# hy        1
# km        1
# Name: count, dtype: int64

# %% [markdown]
# ## Randomize language data: Use appropriate encoding (e.g., one-hot, embeddings)...

# %% [markdown]
# ## Transform release date to a numerical format (e.g., timestamp, days since reference date).

# %%
train_data['release_date'] = pd.to_datetime(train_data['release_date'])
train_data['Year'] = train_data['release_date'].dt.year
train_data['Month'] = train_data['release_date'].dt.month
train_data['Day'] = train_data['release_date'].dt.day

# %%
train_data
# Out:
#        Unnamed: 0      id                  title original_language  \
# 17958       17958    9545                 Sniper                en
# 8423         8423  643586     Willy's Wonderland                en
# 13409       13409  639721    The Addams Family 2                en
# 1110         1110   21191             Sin Nombre                es
# 3804         3804   70057                 Dragon                zh
# ...           ...     ...                    ...               ...
# 6293         6293  335051            God Willing                it
# 5565         5565   20024  The End of the Affair                en
# 4959         4959   43645       The Little Devil                it
# 12889       12889   44741              Malicious                it
# 17130       17130   24655                The Car                en
#
#       release_date  popularity  adult  vote_average  Year  Month  Day
# 17958   1993-01-29      22.982  False           6.2  1993      1   29
# 8423    2021-02-12      33.034  False           6.1  2021      2   12
# 13409   2021-10-01      51.439  False           7.0  2021     10    1
# 1110    2009-03-20      25.632  False           7.6  2009      3   20
# 3804    2011-07-04       9.092  False           7.0  2011      7    4
# ...            ...         ...    ...           ...   ...    ...  ...
# 6293    2015-04-09      11.095  False           6.5  2015      4    9
# 5565    1999-12-03      10.988  False           6.6  1999     12    3
# 4959    1988-07-01       7.101  False           6.7  1988      7    1
# 12889   1973-03-29      35.636  False           7.2  1973      3   29
# 17130   1977-05-12      12.892  False           6.3  1977      5   12
#
# [16000 rows x 11 columns]

# %% [markdown]
# ## Omit the "Release Date" column, as its information has already been separated into individual columns for Year, Month, and Day.

# %%
train_data.drop('release_date', axis=1, inplace=True)

# %%
train_data
# Out:
#        Unnamed: 0      id                    title original_language  \
# 7435         7435  174772            Europa Report                en
# 5078         5078  484510           Trolls Holiday                en
# 2162         2162   79120                  Weekend                en
# 2946         2946     476         Drugstore Cowboy                en
# 19928       19928    9676         The Black Dahlia                en
# ...           ...     ...                      ...               ...
# 10313       10313  714888          Argentina, 1985                es
# 12783       12783   98622                        9                en
# 11241       11241  256040  Bāhubali: The Beginning                te
# 4050         4050   11689            Crime Busters                it
# 11980       11980   12311     Mutiny on the Bounty                en
#
#        popularity  adult  vote_average  Year  Month  Day
# 7435       23.301  False           6.3  2013      6   27
# 5078       16.782  False           6.7  2017     11    1
# 2162       10.652  False           7.3  2011      9   22
# 2946       11.279  False           7.1  1989     10   20
# 19928      14.980  False           5.6  2006      9   15
# ...           ...    ...           ...   ...    ...  ...
# 10313      16.634  False           8.0  2022      9   29
# 12783       4.929  False           7.2  2005      4   21
# 11241      29.343  False           7.6  2015      7   10
# 4050       10.923  False           6.9  1977      4    1
# 11980      14.425  False           7.4  1935     11   22
#
# [16000 rows x 10 columns]

# %% [markdown]
# ## As the title is not easily analyzable and could differ from others (as the train_data is randomly selected from 20% of the entire dataset).

# %%
train_data['title_Length'] = train_data['title'].apply(len)

# %%
train_data.drop('title', axis=1, inplace=True)

# %%
# one-hot encoding
# train_data = pd.get_dummies(train_data, columns=['original_language'], prefix='lang')
train_data['is_english'] = train_data['original_language'].apply(lambda lang: 1 if lang == 'en' else 0)

# %%
train_data.drop('original_language', axis =1, inplace = True)

# %%
train_data.corr()
# Out:
#               Unnamed: 0        id  popularity  adult  vote_average      Year  \
# Unnamed: 0      1.000000 -0.002218   -0.040306    NaN     -0.497604  0.121563
# id             -0.002218  1.000000    0.130883    NaN      0.010146  0.601310
# popularity     -0.040306  0.130883    1.000000    NaN      0.086525  0.099884
# adult                NaN       NaN         NaN    NaN           NaN       NaN
# vote_average   -0.497604  0.010146    0.086525    NaN      1.000000 -0.234478
# Year            0.121563  0.601310    0.099884    NaN     -0.234478  1.000000
# Month          -0.046220 -0.003475   -0.032205    NaN      0.077575 -0.034977
# Day            -0.009341  0.012037    0.000754    NaN      0.020920 -0.008039
# title_Length   -0.038198  0.000735    0.046956    NaN      0.087368 -0.011833
# is_english      0.103550 -0.120621    0.063569    NaN     -0.217041 -0.016556
#
#                  Month       Day  title_Length  is_english
# Unnamed: 0   -0.046220 -0.009341     -0.038198    0.103550
# id           -0.003475  0.012037      0.000735   -0.120621
# popularity   -0.032205  0.000754      0.046956    0.063569
# adult              NaN       NaN           NaN         NaN
# vote_average  0.077575  0.020920      0.087368   -0.217041
# Year         -0.034977 -0.008039     -0.011833   -0.016556
# Month         1.000000 -0.017257      0.029248    0.013133
# Day          -0.017257  1.000000     -0.010034   -0.004239
# title_Length  0.029248 -0.010034      1.000000   -0.039674
# is_english    0.013133 -0.004239     -0.039674    1.000000

# %% [markdown]
# ## Generate a Heatmap to visualize factor correlations

# %%
plt.figure(figsize=(15,8))
sns.heatmap(train_data.corr(), annot=True, cmap="YlGnBu")
# Out:
# <Axes: >

# %%
plt.figure(figsize=(15,8))
sns.scatterplot(x = "popularity", y ="Year", data= train_data, hue = "vote_average", palette="coolwarm")
# Out:
# <Axes: xlabel='popularity', ylabel='Year'>

# %% [markdown]
# # Model Linear Regression

# %%
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

X_train, y_train = train_data.drop(['vote_average'], axis=1), train_data['vote_average']
X_train_s = scaler.fit_transform(X_train)
reg = LinearRegression()

reg.fit(X_train_s, y_train)
# Out:
# LinearRegression()

# %%
X_train
# Out:
#        Unnamed: 0      id  popularity  adult  Year  Month  Day  title_Length  \
# 17958       17958    9545      22.982  False  1993      1   29             6
# 8423         8423  643586      33.034  False  2021      2   12            18
# 13409       13409  639721      51.439  False  2021     10    1            19
# 1110         1110   21191      25.632  False  2009      3   20            10
# 3804         3804   70057       9.092  False  2011      7    4             6
# ...           ...     ...         ...    ...   ...    ...  ...           ...
# 6293         6293  335051      11.095  False  2015      4    9            11
# 5565         5565   20024      10.988  False  1999     12    3            21
# 4959         4959   43645       7.101  False  1988      7    1            16
# 12889       12889   44741      35.636  False  1973      3   29             9
# 17130       17130   24655      12.892  False  1977      5   12             7
#
#        is_english
# 17958           1
# 8423            1
# 13409           1
# 1110            0
# 3804            0
# ...           ...
# 6293            0
# 5565            1
# 4959            0
# 12889           0
# 17130           1
#
# [16000 rows x 9 columns]

# %%
X_test
# Out:
#        Unnamed: 0      id                                    title  \
# 15259       15259    6521                            The Contender
# 9710         9710  215379                               Young Ones
# 14680       14680   12178           Miss Pettigrew Lives for a Day
# 12706       12706   10198                The Princess and the Frog
# 16282       16282  172385                                    Rio 2
# ...           ...     ...                                      ...
# 19255       19255  595743                          SAS: Red Notice
# 14183       14183     953                               Madagascar
# 19646       19646   10040  Miss Congeniality 2: Armed and Fabulous
# 7708         7708   78571                              Being Flynn
# 12976       12976  551271                                 Medieval
#
#       original_language release_date  popularity  adult
# 15259                en   2000-10-13       8.091  False
# 9710                 en   2014-06-28       9.806  False
# 14680                en   2008-03-07      12.172  False
# 12706                en   2009-12-08      74.261  False
# 16282                en   2014-03-19      35.102  False
# ...                 ...          ...         ...    ...
# 19255                en   2021-08-11      34.166  False
# 14183                en   2005-05-25      68.716  False
# 19646                en   2005-03-11      21.288  False
# 7708                 en   2012-03-02       7.062  False
# 12976                en   2022-09-08     115.620  False
#
# [4000 rows x 7 columns]

# %%
test_data = X_test.join(y_test)

test_data['release_date'] = pd.to_datetime(test_data['release_date'])
test_data['Year'] = test_data['release_date'].dt.year
test_data['Month'] = test_data['release_date'].dt.month
test_data['Day'] = test_data['release_date'].dt.day
test_data.drop('release_date', axis=1, inplace=True)
test_data['title_Length'] = test_data['title'].apply(len)
test_data.drop('title', axis=1, inplace=True)
test_data['is_english'] = test_data['original_language'].apply(lambda lang: 1 if lang == 'en' else 0)
test_data.drop('original_language', axis=1, inplace=True)

# %%
X_test, y_test = test_data.drop(['vote_average'], axis=1), test_data['vote_average']

# %%
X_test
# Out:
#        Unnamed: 0      id  popularity  adult  Year  Month  Day  title_Length  \
# 15259       15259    6521       8.091  False  2000     10   13            13
# 9710         9710  215379       9.806  False  2014      6   28            10
# 14680       14680   12178      12.172  False  2008      3    7            30
# 12706       12706   10198      74.261  False  2009     12    8            25
# 16282       16282  172385      35.102  False  2014      3   19             5
# ...           ...     ...         ...    ...   ...    ...  ...           ...
# 19255       19255  595743      34.166  False  2021      8   11            15
# 14183       14183     953      68.716  False  2005      5   25            10
# 19646       19646   10040      21.288  False  2005      3   11            39
# 7708         7708   78571       7.062  False  2012      3    2            11
# 12976       12976  551271     115.620  False  2022      9    8             8
#
#        is_english
# 15259           1
# 9710            1
# 14680           1
# 12706           1
# 16282           1
# ...           ...
# 19255           1
# 14183           1
# 19646           1
# 7708            1
# 12976           1
#
# [4000 rows x 9 columns]

# %%
X_test_s = scaler.fit_transform(X_test)

# %%
reg.score(X_test_s, y_test)
# Out:
# 0.31821896554722584
