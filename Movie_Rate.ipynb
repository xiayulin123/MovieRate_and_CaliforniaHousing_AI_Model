# %% [markdown]
# # Setting Up the Environment

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Get Data from the dataset

# %%
data = pd.read_csv("Movies_data.csv")

# %%
#check the data
data
# Out:
#        Unnamed: 0      id                        title original_language  \
# 0               0     238                The Godfather                en
# 1               1     278     The Shawshank Redemption                en
# 2               2     240        The Godfather Part II                en
# 3               3   19404  Dilwale Dulhania Le Jayenge                hi
# 4               4     424             Schindler's List                en
# ...           ...     ...                          ...               ...
# 19995       19995  384521      The Cloverfield Paradox                en
# 19996       19996   14361                  Captain Ron                en
# 19997       19997   11637            Are We There Yet?                en
# 19998       19998   10956                     Joe Dirt                en
# 19999       19999   72559        G.I. Joe: Retaliation                en
#
#       release_date  vote_average  popularity  adult
# 0       1972-03-14           8.7     114.574  False
# 1       1994-09-23           8.7      91.998  False
# 2       1974-12-20           8.6      61.490  False
# 3       1995-10-20           8.6      28.989  False
# 4       1993-12-15           8.6      43.764  False
# ...            ...           ...         ...    ...
# 19995   2018-02-04           5.6      17.073  False
# 19996   1992-09-18           5.6      11.060  False
# 19997   2005-01-20           5.6      15.591  False
# 19998   2001-04-10           5.6      15.664  False
# 19999   2013-03-27           5.6      40.449  False
#
# [20000 rows x 8 columns]

# %%
#check data if there is any part missing
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         20000 non-null  int64
#  1   id                 20000 non-null  int64
#  2   title              20000 non-null  object
#  3   original_language  20000 non-null  object
#  4   release_date       20000 non-null  object
#  5   vote_average       20000 non-null  float64
#  6   popularity         20000 non-null  float64
#  7   adult              20000 non-null  bool
# dtypes: bool(1), float64(2), int64(2), object(3)
# memory usage: 1.1+ MB

# %% [markdown]
# # Seperate the Data into X and Y
# ## X = independents Y = dependent

# %%
from sklearn.model_selection import train_test_split

#define what x and y is
X = data.drop(['vote_average'], axis=1) #x is the table without vote_average
Y = data['vote_average'] #y is the table only with vote_average

# %%
X
# Out:
#        Unnamed: 0      id                        title original_language  \
# 0               0     238                The Godfather                en
# 1               1     278     The Shawshank Redemption                en
# 2               2     240        The Godfather Part II                en
# 3               3   19404  Dilwale Dulhania Le Jayenge                hi
# 4               4     424             Schindler's List                en
# ...           ...     ...                          ...               ...
# 19995       19995  384521      The Cloverfield Paradox                en
# 19996       19996   14361                  Captain Ron                en
# 19997       19997   11637            Are We There Yet?                en
# 19998       19998   10956                     Joe Dirt                en
# 19999       19999   72559        G.I. Joe: Retaliation                en
#
#       release_date  popularity  adult
# 0       1972-03-14     114.574  False
# 1       1994-09-23      91.998  False
# 2       1974-12-20      61.490  False
# 3       1995-10-20      28.989  False
# 4       1993-12-15      43.764  False
# ...            ...         ...    ...
# 19995   2018-02-04      17.073  False
# 19996   1992-09-18      11.060  False
# 19997   2005-01-20      15.591  False
# 19998   2001-04-10      15.664  False
# 19999   2013-03-27      40.449  False
#
# [20000 rows x 7 columns]

# %%
Y
# Out:
# 0        8.7
# 1        8.7
# 2        8.6
# 3        8.6
# 4        8.6
#         ...
# 19995    5.6
# 19996    5.6
# 19997    5.6
# 19998    5.6
# 19999    5.6
# Name: vote_average, Length: 20000, dtype: float64

# %% [markdown]
# # Seperate into train dataset and test dataset

# %%
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.2)

# %%
#combine the data to traindata set
train_data = X_train.join(y_train)

# %%
train_data
# Out:
#        Unnamed: 0      id                                  title  \
# 1036         1036   12093                           Lilya 4-ever
# 2247         2247   10654                                   Hair
# 10006       10006     389                           12 Angry Men
# 7222         7222   13968                               Jump In!
# 19881       19881   18298                        The Three Kings
# ...           ...     ...                                    ...
# 3907         3907   37950                      Charlie St. Cloud
# 6399         6399   81003  Kung Fu Panda: Secrets of the Masters
# 2222         2222   15003                              Chocolate
# 14190       14190  542928                     The Endless Trench
# 13852       13852   49530                                In Time
#
#       original_language release_date  popularity  adult  vote_average
# 1036                 sv   2002-08-23      14.973  False           7.6
# 2247                 en   1979-03-14      11.945  False           7.3
# 10006                en   1957-04-10      37.808  False           8.5
# 7222                 en   2007-01-12       7.432  False           6.3
# 19881                fr   2001-12-12       7.201  False           5.7
# ...                 ...          ...         ...    ...           ...
# 3907                 en   2010-07-30      15.152  False           6.9
# 6399                 en   2011-12-12      15.807  False           6.5
# 2222                 th   2008-02-06      17.756  False           7.3
# 14190                es   2019-10-31      12.579  False           6.9
# 13852                en   2011-10-27      57.069  False           7.0
#
# [16000 rows x 8 columns]

# %%
train_data.original_language.value_counts()
# Out:
# original_language
# en    12069
# fr     1113
# it      705
# ja      527
# es      368
# de      179
# ko      174
# cn      113
# zh      110
# ru       85
# hi       83
# pt       78
# da       58
# sv       58
# no       45
# pl       37
# nl       29
# tr       22
# th       20
# fa       17
# hu       13
# fi       13
# id       12
# cs        7
# el        7
# is        7
# sr        5
# uk        5
# ar        5
# te        4
# eu        4
# xx        3
# ro        3
# ml        2
# la        2
# tn        2
# et        2
# he        2
# bs        2
# bn        2
# km        2
# gl        2
# mk        1
# nb        1
# hy        1
# sh        1
# Name: count, dtype: int64

# %% [markdown]
# ## Randomize language data: Use appropriate encoding (e.g., one-hot, embeddings)...

# %% [markdown]
# ## Transform release date to a numerical format (e.g., timestamp, days since reference date).

# %%
train_data['release_date'] = pd.to_datetime(train_data['release_date'])
train_data['Year'] = train_data['release_date'].dt.year
train_data['Month'] = train_data['release_date'].dt.month
train_data['Day'] = train_data['release_date'].dt.day

# %%
train_data
# Out:
#        Unnamed: 0      id                                  title  \
# 1036         1036   12093                           Lilya 4-ever
# 2247         2247   10654                                   Hair
# 10006       10006     389                           12 Angry Men
# 7222         7222   13968                               Jump In!
# 19881       19881   18298                        The Three Kings
# ...           ...     ...                                    ...
# 3907         3907   37950                      Charlie St. Cloud
# 6399         6399   81003  Kung Fu Panda: Secrets of the Masters
# 2222         2222   15003                              Chocolate
# 14190       14190  542928                     The Endless Trench
# 13852       13852   49530                                In Time
#
#       original_language release_date  popularity  adult  vote_average  Year  \
# 1036                 sv   2002-08-23      14.973  False           7.6  2002
# 2247                 en   1979-03-14      11.945  False           7.3  1979
# 10006                en   1957-04-10      37.808  False           8.5  1957
# 7222                 en   2007-01-12       7.432  False           6.3  2007
# 19881                fr   2001-12-12       7.201  False           5.7  2001
# ...                 ...          ...         ...    ...           ...   ...
# 3907                 en   2010-07-30      15.152  False           6.9  2010
# 6399                 en   2011-12-12      15.807  False           6.5  2011
# 2222                 th   2008-02-06      17.756  False           7.3  2008
# 14190                es   2019-10-31      12.579  False           6.9  2019
# 13852                en   2011-10-27      57.069  False           7.0  2011
#
#        Month  Day
# 1036       8   23
# 2247       3   14
# 10006      4   10
# 7222       1   12
# 19881     12   12
# ...      ...  ...
# 3907       7   30
# 6399      12   12
# 2222       2    6
# 14190     10   31
# 13852     10   27
#
# [16000 rows x 11 columns]

# %% [markdown]
# ## Omit the "Release Date" column, as its information has already been separated into individual columns for Year, Month, and Day.

# %%
train_data.drop('release_date', axis=1, inplace=True)

# %%
train_data
# Out:
#        Unnamed: 0      id                                  title  \
# 1036         1036   12093                           Lilya 4-ever
# 2247         2247   10654                                   Hair
# 10006       10006     389                           12 Angry Men
# 7222         7222   13968                               Jump In!
# 19881       19881   18298                        The Three Kings
# ...           ...     ...                                    ...
# 3907         3907   37950                      Charlie St. Cloud
# 6399         6399   81003  Kung Fu Panda: Secrets of the Masters
# 2222         2222   15003                              Chocolate
# 14190       14190  542928                     The Endless Trench
# 13852       13852   49530                                In Time
#
#       original_language  popularity  adult  vote_average  Year  Month  Day
# 1036                 sv      14.973  False           7.6  2002      8   23
# 2247                 en      11.945  False           7.3  1979      3   14
# 10006                en      37.808  False           8.5  1957      4   10
# 7222                 en       7.432  False           6.3  2007      1   12
# 19881                fr       7.201  False           5.7  2001     12   12
# ...                 ...         ...    ...           ...   ...    ...  ...
# 3907                 en      15.152  False           6.9  2010      7   30
# 6399                 en      15.807  False           6.5  2011     12   12
# 2222                 th      17.756  False           7.3  2008      2    6
# 14190                es      12.579  False           6.9  2019     10   31
# 13852                en      57.069  False           7.0  2011     10   27
#
# [16000 rows x 10 columns]

# %% [markdown]
# ## As the title is not easily analyzable and could differ from others (as the train_data is randomly selected from 20% of the entire dataset).

# %%
train_data['title_Length'] = train_data['title'].apply(len)

# %%
train_data.drop('title', axis=1, inplace=True)

# %%
# one-hot encoding
# train_data = pd.get_dummies(train_data, columns=['original_language'], prefix='lang')
train_data['is_english'] = train_data['original_language'].apply(lambda lang: 1 if lang == 'en' else 0)

# %%
train_data.drop('original_language', axis =1, inplace = True)

# %%
train_data.corr()
# Out:
#               Unnamed: 0        id  popularity  adult  vote_average      Year  \
# Unnamed: 0      1.000000 -0.001448   -0.039796    NaN     -0.497786  0.116299
# id             -0.001448  1.000000    0.125188    NaN      0.010009  0.600122
# popularity     -0.039796  0.125188    1.000000    NaN      0.084961  0.098911
# adult                NaN       NaN         NaN    NaN           NaN       NaN
# vote_average   -0.497786  0.010009    0.084961    NaN      1.000000 -0.233668
# Year            0.116299  0.600122    0.098911    NaN     -0.233668  1.000000
# Month          -0.032885 -0.008656   -0.032851    NaN      0.075906 -0.036873
# Day            -0.009937  0.010120    0.002467    NaN      0.024872 -0.004440
# title_Length   -0.038278 -0.011952    0.043525    NaN      0.083270 -0.020105
# is_english      0.106709 -0.119309    0.058961    NaN     -0.216195 -0.013354
#
#                  Month       Day  title_Length  is_english
# Unnamed: 0   -0.032885 -0.009937     -0.038278    0.106709
# id           -0.008656  0.010120     -0.011952   -0.119309
# popularity   -0.032851  0.002467      0.043525    0.058961
# adult              NaN       NaN           NaN         NaN
# vote_average  0.075906  0.024872      0.083270   -0.216195
# Year         -0.036873 -0.004440     -0.020105   -0.013354
# Month         1.000000 -0.007877      0.030583    0.008192
# Day          -0.007877  1.000000     -0.009361   -0.003058
# title_Length  0.030583 -0.009361      1.000000   -0.038196
# is_english    0.008192 -0.003058     -0.038196    1.000000

# %% [markdown]
# ## Generate a Heatmap to visualize factor correlations

# %%
plt.figure(figsize=(15,8))
sns.heatmap(train_data.corr(), annot=True, cmap="YlGnBu")
# Out:
# <Axes: >

# %%
plt.figure(figsize=(15,8))
sns.scatterplot(x = "popularity", y ="Year", data= train_data, hue = "vote_average", palette="coolwarm")
# Out:
# <Axes: xlabel='popularity', ylabel='Year'>

# %% [markdown]
# # Model Linear Regression

# %%
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

X_train, y_train = train_data.drop(['vote_average'], axis=1), train_data['vote_average']
X_train_s = scaler.fit_transform(X_train)
reg = LinearRegression()

reg.fit(X_train_s, y_train)
# Out:
# LinearRegression()

# %%
X_train
# Out:
#        Unnamed: 0      id  popularity  adult  Year  Month  Day  title_Length  \
# 1036         1036   12093      14.973  False  2002      8   23            12
# 2247         2247   10654      11.945  False  1979      3   14             4
# 10006       10006     389      37.808  False  1957      4   10            12
# 7222         7222   13968       7.432  False  2007      1   12             8
# 19881       19881   18298       7.201  False  2001     12   12            15
# ...           ...     ...         ...    ...   ...    ...  ...           ...
# 3907         3907   37950      15.152  False  2010      7   30            17
# 6399         6399   81003      15.807  False  2011     12   12            37
# 2222         2222   15003      17.756  False  2008      2    6             9
# 14190       14190  542928      12.579  False  2019     10   31            18
# 13852       13852   49530      57.069  False  2011     10   27             7
#
#        is_english
# 1036            0
# 2247            1
# 10006           1
# 7222            1
# 19881           0
# ...           ...
# 3907            1
# 6399            1
# 2222            0
# 14190           0
# 13852           1
#
# [16000 rows x 9 columns]

# %%
X_test
# Out:
#        Unnamed: 0      id                           title original_language  \
# 19695       19695  137145          247 Degrees Fahrenheit                en
# 366           366     640             Catch Me If You Can                en
# 5572         5572    7446                  Tropic Thunder                en
# 9033         9033   20329  Death Note: L Change the World                ja
# 14123       14123   15058                           Speak                en
# ...           ...     ...                             ...               ...
# 11765       11765  137106                  The Lego Movie                en
# 8640         8640    5559                       Bee Movie                en
# 4275         4275  755566                       Day Shift                en
# 7436         7436   50698                Grave Encounters                en
# 2194         2194  271674                 Suite Française                en
#
#       release_date  popularity  adult
# 19695   2011-09-01       6.819  False
# 366     2002-12-16      73.356  False
# 5572    2008-08-09      28.379  False
# 9033    2008-02-07      16.092  False
# 14123   2004-01-20      10.381  False
# ...            ...         ...    ...
# 11765   2014-02-06      37.580  False
# 8640    2007-10-28      29.050  False
# 4275    2022-08-12      71.141  False
# 7436    2011-09-09      12.487  False
# 2194    2015-03-12      12.212  False
#
# [4000 rows x 7 columns]

# %%
test_data = X_test.join(y_test)

test_data['release_date'] = pd.to_datetime(test_data['release_date'])
test_data['Year'] = test_data['release_date'].dt.year
test_data['Month'] = test_data['release_date'].dt.month
test_data['Day'] = test_data['release_date'].dt.day
test_data.drop('release_date', axis=1, inplace=True)
test_data['title_Length'] = test_data['title'].apply(len)
test_data.drop('title', axis=1, inplace=True)
test_data['is_english'] = test_data['original_language'].apply(lambda lang: 1 if lang == 'en' else 0)
test_data.drop('original_language', axis=1, inplace=True)

# %%
X_test, y_test = test_data.drop(['vote_average'], axis=1), test_data['vote_average']

# %%
X_test
# Out:
#        Unnamed: 0      id  popularity  adult  Year  Month  Day  title_Length  \
# 19695       19695  137145       6.819  False  2011      9    1            22
# 366           366     640      73.356  False  2002     12   16            19
# 5572         5572    7446      28.379  False  2008      8    9            14
# 9033         9033   20329      16.092  False  2008      2    7            30
# 14123       14123   15058      10.381  False  2004      1   20             5
# ...           ...     ...         ...    ...   ...    ...  ...           ...
# 11765       11765  137106      37.580  False  2014      2    6            14
# 8640         8640    5559      29.050  False  2007     10   28             9
# 4275         4275  755566      71.141  False  2022      8   12             9
# 7436         7436   50698      12.487  False  2011      9    9            16
# 2194         2194  271674      12.212  False  2015      3   12            15
#
#        is_english
# 19695           1
# 366             1
# 5572            1
# 9033            0
# 14123           1
# ...           ...
# 11765           1
# 8640            1
# 4275            1
# 7436            1
# 2194            1
#
# [4000 rows x 9 columns]

# %%
X_test_s = scaler.fit_transform(X_test)

# %%
reg.score(X_test_s, y_test)
# Out:
# 0.3168897590059897

# %% [markdown]
# # Model Random Forest Regression

# %%
from sklearn.ensemble import RandomForestRegressor

forest = RandomForestRegressor()
forest.fit(X_train_s, y_train)
# Out:
# RandomForestRegressor()

# %%
forest.score(X_test_s, y_test)
# Out:
# 0.7719478427576557

# %% [markdown]
# # Model Cross Validation

# %%
from sklearn.model_selection import GridSearchCV

fores = RandomForestRegressor()
param_grid = {
    "n_estimators":[3, 10, 30],
    "max_features":[2,4,6,8]
}
grid_search = GridSearchCV(forest, param_grid, cv =5, scoring = "neg_mean_squared_error", return_train_score = True)
grid_search.fit(X_train_s, y_train)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestRegressor(),
#              param_grid={'max_features': [2, 4, 6, 8],
#                          'n_estimators': [3, 10, 30]},
#              return_train_score=True, scoring='neg_mean_squared_error')

# %%
best_forest = grid_search.best_estimator_

# %%
best_forest.score(X_test_s, y_test)
# Out:
# 0.7846617673229391

# %% [markdown]
# ## Model Random Forest Regression More Accurate

# %%
from sklearn.model_selection import GridSearchCV

fores = RandomForestRegressor()
param_grid = {
    "n_estimators":[100, 200, 300],
    "max_features":[2,4],
    "max_depth":[None, 4, 8]
}
grid_search = GridSearchCV(forest, param_grid, cv =5, scoring = "neg_mean_squared_error", return_train_score = True)
grid_search.fit(X_train_s, y_train)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestRegressor(),
#              param_grid={'max_depth': [None, 4, 8], 'max_features': [2, 4],
#                          'n_estimators': [100, 200, 300]},
#              return_train_score=True, scoring='neg_mean_squared_error')

# %%
grid_search.best_estimator_
# Out:
# RandomForestRegressor(max_features=4)

# %%
grid_search.best_estimator_.score(X_test_s, y_test)
# Out:
# 0.8587943462431646
